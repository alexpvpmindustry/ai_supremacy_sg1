# %%
import pandas as pd

# Replace with your Google Sheet URL
"https://docs.google.com/spreadsheets/d/1vOOXZ3XaL15mY5fmBMlzfcWNMNYGQLOhuJQf_Z-Exmg/edit?gid=0#gid=0"
url = 'https://docs.google.com/spreadsheets/d/1vOOXZ3XaL15mY5fmBMlzfcWNMNYGQLOhuJQf_Z-Exmg/export?format=csv'

# Fetch the data
df = pd.read_csv(url,skiprows=2)

# Save the data to a CSV file
df.to_csv('output.csv', index=False)

print("Data has been successfully exported to output.csv")
# Out:
# Data has been successfully exported to output.csv

# %%
df
# Out:
#       Company / Group Name                                  Website URL  \
# 0              Recursal AI  https://recursal.ai\nhttps://featherless.ai
# 1                  Reka AI                         https://www.reka.ai/
# 2                 Homebrew       https://homebrew.ltd/\nhttps://jan.ai/
# 3                Uilicious                        https://uilicious.com
# 4                   Lucene                          https://lucence.com
# 5                Opilot AI                       https://www.opilot.ai/
# 6                   Siftee                            https://Siftee.io
# 7   HiCura Medical Pte Ltd                   https://hicuramedical.com/
# 8                   Kabana                       https://usekabana.com/
# 9         Genta Technology                          https://genta.tech/
# 10             JigsawStack                     https://jigsawstack.com/
# 11              AIPath.one                       https://www.aipath.one
# ...

# %%
print(df["Short Description"][0])
# Out:
# - Next Generation Foundation model with 100x lower inference cost
# - World's largest collection of OSS models, in a single API platform
